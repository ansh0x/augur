# %%
import pandas as pd
import json

# %%
train = "train.json"
test = "test.json"

# %%
with open(train, "r") as f:
    data=json.load(f)

# %%
info_df = pd.DataFrame([data["info"]])  # single dict
audio_df = pd.DataFrame(data["audio"])
categories_df = pd.DataFrame(data["categories"])
annotations_df = pd.DataFrame(data["annotations"])
licenses_df = pd.DataFrame(data["licenses"])

# %%
audio_df
# Out:
#             id  duration                                          file_name  \
# 0       156691     4.296  train/03612_Animalia_Chordata_Aves_Passeriform...
# 1       182163     2.333  train/04361_Animalia_Chordata_Aves_Passeriform...
# 2        19703    15.250  train/00911_Animalia_Chordata_Amphibia_Anura_H...
# 3        61500    18.795  train/02061_Animalia_Chordata_Aves_Cuculiforme...
# 4       224298    13.700  train/05147_Animalia_Chordata_Aves_Strigiforme...
# ...        ...       ...                                                ...
# 137007  139505     1.889  train/03479_Animalia_Chordata_Aves_Passeriform...
# 137008  102836     7.392  train/02760_Animalia_Chordata_Aves_Passeriform...
# 137009  135022    17.579  train/03448_Animalia_Chordata_Aves_Passeriform...
# 137010   73921     5.250  train/02376_Animalia_Chordata_Aves_Passeriform...
# 137011   31711    10.937  train/01182_Animalia_Chordata_Amphibia_Anura_M...
#
#         license   rights_holder                       date   latitude  \
# 0             0    Katie Kucera  2019-04-15T11:23:00-05:00  42.151129
# 1             1    Jean Suplick  2021-09-23T09:12:00-05:00  33.038882
# 2             1  Chris Harrison  2015-04-25T20:58:00-05:00  29.313880
# 3             1          tkp123  2021-03-14T16:16:00+08:00  22.335805
# 4             0  Giacomo Piazza  2021-04-24T22:11:32+02:00  44.482806
# ...         ...             ...                        ...        ...
# 137007        1       Jeff Ward  2021-04-16T09:31:00-07:00  44.058730
# 137008        0  John A Haskins  2020-04-29T14:10:14-07:00  48.051094
# 137009        1          mattvw  2020-10-09T16:37:03-07:00  40.859607
# 137010        1         Haley H                 2020-04-26  47.025984
# 137011        1    Mango parker  2021-08-14T09:10:08+09:30 -35.389865
#
#          longitude  location_uncertainty
# 0       -87.788503                   8.0
# 1       -96.664071                 277.0
# 2       -98.991786                   NaN
# 3       114.149489                1106.0
# 4        11.278064                  65.0
# ...            ...                   ...
# 137007 -123.095116                  17.0
# 137008 -123.054914                   NaN
# 137009 -124.091515                   5.0
# 137010 -122.893084                   NaN
# 137011  138.463698                 115.0
#
# [137012 rows x 9 columns]

# %%
categories_df
# Out:
#         id                    name                        common_name  \
# 0        0  Hodotermes mossambicus         Northern Harvester Termite
# 1        1      Brachinus sclopeta
# 2        2  Acanthinodera cumingii
# 3        3     Agapanthia violacea
# 4        4   Anoplophora chinensis          Citrus Long-horned Beetle
# ...    ...                     ...                                ...
# 5564  5564        Crotalus pyrrhus  Southwestern Speckled Rattlesnake
# 5565  5565          Crotalus ruber            Red Diamond Rattlesnake
# 5566  5566        Crotalus viridis                Prairie Rattlesnake
# 5567  5567     Sistrurus catenatus                         Massasauga
# 5568  5568            Vipera aspis                          Asp Viper
#
#      supercategory   kingdom      phylum     class       order  \
# 0          Insecta  Animalia  Arthropoda   Insecta   Blattodea
# 1          Insecta  Animalia  Arthropoda   Insecta  Coleoptera
# 2          Insecta  Animalia  Arthropoda   Insecta  Coleoptera
# 3          Insecta  Animalia  Arthropoda   Insecta  Coleoptera
# 4          Insecta  Animalia  Arthropoda   Insecta  Coleoptera
# ...            ...       ...         ...       ...         ...
# 5564      Reptilia  Animalia    Chordata  Reptilia    Squamata
# 5565      Reptilia  Animalia    Chordata  Reptilia    Squamata
# 5566      Reptilia  Animalia    Chordata  Reptilia    Squamata
# 5567      Reptilia  Animalia    Chordata  Reptilia    Squamata
# 5568      Reptilia  Animalia    Chordata  Reptilia    Squamata
#
#               family          genus specific_epithet  \
# 0     Hodotermitidae     Hodotermes      mossambicus
# 1          Carabidae      Brachinus         sclopeta
# 2       Cerambycidae  Acanthinodera         cumingii
# 3       Cerambycidae     Agapanthia         violacea
# 4       Cerambycidae    Anoplophora        chinensis
# ...              ...            ...              ...
# 5564       Viperidae       Crotalus          pyrrhus
# 5565       Viperidae       Crotalus            ruber
# 5566       Viperidae       Crotalus          viridis
# 5567       Viperidae      Sistrurus        catenatus
# 5568       Viperidae         Vipera            aspis
#
#                                          audio_dir_name  evaluation
# 0     00000_Animalia_Arthropoda_Insecta_Blattodea_Ho...           0
# 1     00001_Animalia_Arthropoda_Insecta_Coleoptera_C...           0
# 2     00002_Animalia_Arthropoda_Insecta_Coleoptera_C...           0
# 3     00003_Animalia_Arthropoda_Insecta_Coleoptera_C...           0
# 4     00004_Animalia_Arthropoda_Insecta_Coleoptera_C...           0
# ...                                                 ...         ...
# 5564  05564_Animalia_Chordata_Reptilia_Squamata_Vipe...           0
# 5565  05565_Animalia_Chordata_Reptilia_Squamata_Vipe...           0
# 5566  05566_Animalia_Chordata_Reptilia_Squamata_Vipe...           0
# 5567  05567_Animalia_Chordata_Reptilia_Squamata_Vipe...           0
# 5568  05568_Animalia_Chordata_Reptilia_Squamata_Vipe...           0
#
# [5569 rows x 13 columns]

# %%
annot_cat = annotations_df.merge(categories_df,
                                 left_on="category_id",
                                 right_on="id",
                                 suffixes=("_annot", "_cat"))
print(annot_cat[["audio_id", "name", "common_name"]].head())
# Out:
#    audio_id                    name               common_name
# 0    156691  Zonotrichia albicollis    White-throated Sparrow
# 1    182163       Troglodytes aedon                House Wren
# 2     19703        Acris blanchardi  Blanchard's Cricket Frog
# 3     61500   Eudynamys scolopaceus                Asian Koel
# 4    224298              Otus scops        Eurasian Scops Owl

# %%
annot_cat
# Out:
#         id_annot  audio_id  category_id  id_cat                    name  \
# 0         156691    156691         3612    3612  Zonotrichia albicollis
# 1         182163    182163         4361    4361       Troglodytes aedon
# 2          19703     19703          911     911        Acris blanchardi
# 3          61500     61500         2061    2061   Eudynamys scolopaceus
# 4         224298    224298         5147    5147              Otus scops
# ...          ...       ...          ...     ...                     ...
# 137007    139505    139505         3479    3479      Leiothlypis celata
# 137008    102836    102836         2760    2760          Spinus tristis
# 137009    135022    135022         3448    3448    Poecile atricapillus
# 137010     73921     73921         2376    2376    Psaltriparus minimus
# 137011     31711     31711         1182    1182        Crinia signifera
#
#                      common_name supercategory   kingdom    phylum     class  \
# 0         White-throated Sparrow          Aves  Animalia  Chordata      Aves
# 1                     House Wren          Aves  Animalia  Chordata      Aves
# 2       Blanchard's Cricket Frog      Amphibia  Animalia  Chordata  Amphibia
# 3                     Asian Koel          Aves  Animalia  Chordata      Aves
# 4             Eurasian Scops Owl          Aves  Animalia  Chordata      Aves
# ...                          ...           ...       ...       ...       ...
# 137007    Orange-crowned Warbler          Aves  Animalia  Chordata      Aves
# 137008        American Goldfinch          Aves  Animalia  Chordata      Aves
# 137009    Black-capped Chickadee          Aves  Animalia  Chordata      Aves
# 137010                   Bushtit          Aves  Animalia  Chordata      Aves
# 137011    Common Eastern Froglet      Amphibia  Animalia  Chordata  Amphibia
#
#                 order          family         genus specific_epithet  \
# 0       Passeriformes   Passerellidae   Zonotrichia       albicollis
# 1       Passeriformes   Troglodytidae   Troglodytes            aedon
# 2               Anura         Hylidae         Acris       blanchardi
# 3        Cuculiformes       Cuculidae     Eudynamys      scolopaceus
# 4        Strigiformes       Strigidae          Otus            scops
# ...               ...             ...           ...              ...
# 137007  Passeriformes       Parulidae   Leiothlypis           celata
# 137008  Passeriformes    Fringillidae        Spinus          tristis
# 137009  Passeriformes         Paridae       Poecile     atricapillus
# 137010  Passeriformes    Aegithalidae  Psaltriparus          minimus
# 137011          Anura  Myobatrachidae        Crinia        signifera
#
#                                            audio_dir_name  evaluation
# 0       03612_Animalia_Chordata_Aves_Passeriformes_Pas...           1
# 1       04361_Animalia_Chordata_Aves_Passeriformes_Tro...           1
# 2       00911_Animalia_Chordata_Amphibia_Anura_Hylidae...           1
# 3       02061_Animalia_Chordata_Aves_Cuculiformes_Cucu...           1
# 4       05147_Animalia_Chordata_Aves_Strigiformes_Stri...           1
# ...                                                   ...         ...
# 137007  03479_Animalia_Chordata_Aves_Passeriformes_Par...           1
# 137008  02760_Animalia_Chordata_Aves_Passeriformes_Fri...           1
# 137009  03448_Animalia_Chordata_Aves_Passeriformes_Par...           1
# 137010  02376_Animalia_Chordata_Aves_Passeriformes_Aeg...           1
# 137011  01182_Animalia_Chordata_Amphibia_Anura_Myobatr...           1
#
# [137012 rows x 16 columns]

# %%
annot_cat.supercategory.value_counts()
# Out:
# supercategory
# Aves        111029
# Amphibia     13183
# Insecta      10080
# Mammalia      2566
# Reptilia       154
# Name: count, dtype: int64

# %%
class_counts = (
    categories_df
    .groupby("supercategory")["id"]
    .nunique()
    .reset_index(name="num_species")
)

class_counts
# Out:
#   supercategory  num_species
# 0      Amphibia          650
# 1          Aves         3846
# 2       Insecta          745
# 3      Mammalia          296
# 4      Reptilia           32
